# %%
import sys, os
sys.path.append(os.path.abspath('..'))  # go up one level from notebooks/

# %%
import nfl_data_py as nfl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import duckdb as db
from utils.wp_predict import predict_wps

# ✅ Set display precision HERE
pd.set_option('display.precision', 6)
# Optional: to ensure everything aligns nicely
pd.options.display.float_format = '{:.6f}'.format

# %%
seasons = list(range(2015, 2025))
pbp = nfl.import_pbp_data(seasons)

print(pbp.shape)
# Out:
# 2015 done.
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# 2022 done.
# 2023 done.
# 2024 done.
# Downcasting floats.
# (483605, 398)

# %%
pbp[['game_id','play_id','season','posteam','defteam','score_differential','wp']].head(100)
# Out:
#             game_id     play_id  season posteam defteam  score_differential  \
# 0   2015_01_BAL_DEN    1.000000    2015    None    None                 NaN
# 1   2015_01_BAL_DEN   36.000000    2015     BAL     DEN            0.000000
# 2   2015_01_BAL_DEN   51.000000    2015     BAL     DEN            0.000000
# 3   2015_01_BAL_DEN   75.000000    2015     BAL     DEN            0.000000
# 4   2015_01_BAL_DEN   96.000000    2015     BAL     DEN            0.000000
# ..              ...         ...     ...     ...     ...                 ...
# 95  2015_01_BAL_DEN 2075.000000    2015     DEN     BAL           -1.000000
# 96  2015_01_BAL_DEN 2099.000000    2015     DEN     BAL           -1.000000
# 97  2015_01_BAL_DEN 2125.000000    2015     BAL     DEN            1.000000
# 98  2015_01_BAL_DEN 2149.000000    2015     BAL     DEN            1.000000
# 99  2015_01_BAL_DEN 2170.000000    2015     BAL     DEN            1.000000
#
#          wp
# 0  0.422024
# 1  0.422024
# 2  0.422024
# 3  0.420599
# 4  0.403295
# ..      ...
# 95 0.486117
# 96 0.468685
# 97 0.564145
# 98 0.614148
# 99 0.610461
#
# [100 rows x 7 columns]

# %%
con = db.connect()
con.register("plays", pbp)

df = con.sql("""
WITH tries AS (
  SELECT
    season,
    game_id,
    play_id,
    qtr,
    game_seconds_remaining,
    posteam AS team,                  -- team attempting the try (the leader)
    two_point_attempt,
    LOWER(COALESCE(two_point_conv_result,'')) AS two_point_conv_result,
    extra_point_attempt,
    LOWER(COALESCE(extra_point_result,''))     AS extra_point_result,
    wp,
    "desc"
  FROM plays
  WHERE qtr = 4
    AND score_differential = 7                 -- pre-try margin +7 for the try team
    AND (two_point_attempt = 1 OR extra_point_attempt = 1)
),
-- If a game has multiple qualifying tries (rare: penalties/retries), keep the first
dedup AS (
  SELECT
    *,
    ROW_NUMBER() OVER (PARTITION BY game_id ORDER BY play_id) AS rn
  FROM tries
)
SELECT
  season,
  game_id,
  qtr,
  team               AS leading_team,
  game_seconds_remaining,
  wp,
  (two_point_attempt = 1) AS went_for_two,
  CASE WHEN two_point_attempt = 1 THEN (two_point_conv_result = 'success') END AS two_point_success,
  extra_point_result,
  "desc"
FROM dedup
WHERE rn = 1
ORDER BY game_id
""").df()

# %%
sd7_Q4 = df.copy()

# manually correcting timestamps to align with PFR
sd7_Q4.loc[0, "game_seconds_remaining"] = 632
sd7_Q4.loc[1, "game_seconds_remaining"] = 594
sd7_Q4.loc[2, "game_seconds_remaining"] = 177
sd7_Q4.loc[3, "game_seconds_remaining"] = 559
sd7_Q4.loc[4, "game_seconds_remaining"] = 449
sd7_Q4.loc[5, "game_seconds_remaining"] = 698
sd7_Q4.loc[6, "game_seconds_remaining"] = 707
sd7_Q4.loc[7, "game_seconds_remaining"] = 568
sd7_Q4.loc[9, "game_seconds_remaining"] = 582

# %%
# Compute post-try WPs (leader perspective)
branches = sd7_Q4.apply(predict_wps, axis=1, base_margin=23)
sd7_Q4 = sd7_Q4.join(branches)
sd7_Q4.shape
sd7_Q4.head(50)
# Out:
#     season          game_id      qtr leading_team  game_seconds_remaining  \
# 0     2015   2015_01_GB_CHI 4.000000           GB              632.000000
# 1     2015   2015_01_NO_ARI 4.000000          ARI              594.000000
# 2     2015  2015_03_IND_TEN 4.000000          IND              177.000000
# 3     2015   2015_03_TB_HOU 4.000000          HOU              559.000000
# 4     2015   2015_04_CLE_SD 4.000000          LAC              449.000000
# 5     2015   2015_09_TEN_NO 4.000000           NO              698.000000
# 6     2015  2015_11_DEN_CHI 4.000000          DEN              707.000000
# 7     2015  2015_17_PHI_NYG 4.000000          PHI              568.000000
# 8     2016   2016_06_CAR_NO 4.000000           NO              362.000000
# 9     2016  2016_08_NYJ_CLE 4.000000          NYJ              582.000000
# 10    2016   2016_10_SEA_NE 4.000000          SEA              264.000000
# 11    2016  2016_12_CAR_OAK 4.000000          CAR              806.000000
# 12    2016   2016_12_KC_DEN 4.000000          DEN              180.000000
# 13    2016  2016_13_WAS_ARI 4.000000          ARI              116.000000
# 14    2017    2017_01_KC_NE 4.000000           KC              314.000000
# 15    2018  2018_04_CLE_OAK 4.000000          CLE              260.000000
# 16    2018  2018_13_WAS_PHI 4.000000          PHI              850.000000
# 17    2019  2019_01_WAS_PHI 4.000000          PHI              895.000000
# 18    2019  2019_05_JAX_CAR 4.000000          CAR              214.000000
# 19    2019  2019_09_DAL_NYG 4.000000          DAL              760.000000
# 20    2019  2019_13_WAS_CAR 4.000000          WAS              549.000000
# 21    2019   2019_18_TEN_NE 4.000000          TEN                9.000000
# 22    2020   2020_04_BUF_LV 4.000000          BUF              889.000000
# 23    2020   2020_04_NYG_LA 4.000000           LA              416.000000
# 24    2020  2020_06_HOU_TEN 4.000000          HOU              110.000000
# 25    2020  2020_12_CLE_JAX 4.000000          CLE              853.000000
# 26    2021  2021_03_IND_TEN 4.000000          TEN              776.000000
# 27    2021  2021_04_WAS_ATL 4.000000          ATL              892.000000
# 28    2021   2021_08_SF_CHI 4.000000           SF              394.000000
# 29    2021   2021_13_WAS_LV 4.000000          WAS              808.000000
# 30    2021   2021_15_KC_LAC 4.000000          LAC              569.000000
# 31    2021  2021_16_JAX_NYJ 4.000000          NYJ              556.000000
# 32    2022  2022_01_JAX_WAS 4.000000          JAX              705.000000
# 33    2022    2022_05_LV_KC 4.000000           KC              445.000000
# 34    2022   2022_06_TB_PIT 4.000000          PIT              595.000000
# 35    2022   2022_13_GB_CHI 4.000000           GB              111.000000
# 36    2022  2022_15_ARI_DEN 4.000000          DEN              660.000000
# 37    2022  2022_16_NYG_MIN 4.000000          MIN              180.000000
# 38    2022   2022_22_KC_PHI 4.000000           KC              562.000000
# 39    2023   2023_13_CLE_LA 4.000000           LA              228.000000
# 40    2023  2023_13_SEA_DAL 4.000000          SEA              857.000000
# 41    2023   2023_17_LA_NYG 4.000000           LA              723.000000
# 42    2024   2024_08_MIN_LA 4.000000           LA              377.000000
# 43    2024  2024_11_IND_NYJ 4.000000          NYJ              783.000000
# 44    2024  2024_12_BAL_LAC 4.000000          BAL              752.000000
# 45    2024  2024_12_DAL_WAS 4.000000          DAL               14.000000
# 46    2024    2024_13_LA_NO 4.000000           LA              897.000000
# 47    2024   2024_18_CHI_GB 4.000000          CHI              602.000000
# 48    2024    2024_18_NO_TB 4.000000           TB              111.000000
# 49    2024   2024_20_HOU_KC 4.000000           KC              712.000000
#
#          wp  went_for_two  two_point_success extra_point_result  \
# 0  0.835824         False               <NA>               good
# 1  0.857182         False               <NA>               good
# 2  0.930985         False               <NA>               good
# 3  0.855037         False               <NA>             failed
# 4  0.868127         False               <NA>               good
# 5  0.839829         False               <NA>               good
# 6  0.814417         False               <NA>               good
# 7  0.837419         False               <NA>               good
# 8  0.890421         False               <NA>               good
# 9  0.832856         False               <NA>               good
# 10 0.872367          True              False
# 11 0.817059         False               <NA>               good
# 12 0.946181         False               <NA>               good
# 13 0.938805         False               <NA>               good
# 14 0.881245         False               <NA>               good
# 15 0.903754         False               <NA>               good
# 16 0.832681          True               True
# 17 0.826333          True               True
# 18 0.927124         False               <NA>             failed
# 19 0.816175         False               <NA>               good
# 20 0.834994         False               <NA>               good
# 21 0.985510          True              False
# 22 0.816983         False               <NA>             failed
# 23 0.880198         False               <NA>               good
# 24 0.929343          True              False
# 25 0.814439         False               <NA>               good
# 26 0.843247          True               True
# 27 0.844168         False               <NA>               good
# 28 0.860556         False               <NA>               good
# 29 0.817262         False               <NA>               good
# 30 0.855042         False               <NA>               good
# 31 0.855058         False               <NA>               good
# 32 0.819377         False               <NA>               good
# 33 0.863836          True              False
# 34 0.854587         False               <NA>               good
# 35 0.922233          True               True
# 36 0.845806         False               <NA>               good
# 37 0.937351         False               <NA>               good
# 38 0.835794         False               <NA>               good
# 39 0.928179         False               <NA>               good
# 40 0.816171         False               <NA>               good
# 41 0.816175         False               <NA>             failed
# 42 0.884368         False               <NA>               good
# 43 0.840762         False               <NA>               good
# 44 0.818261          True              False
# 45 0.988063         False               <NA>               good
# 46 0.816983         False               <NA>               good
# 47 0.832856         False               <NA>               good
# 48 0.938850         False               <NA>               good
# 49 0.839666         False               <NA>               good
#
#                                                  desc  wp_fail  wp_xp_good  \
# 0   2-M.Crosby extra point is GOOD, Center-61-B.Go... 0.996740    0.996740
# 1   7-C.Catanzaro extra point is GOOD, Center-82-M... 0.997202    0.997202
# 2   4-A.Vinatieri extra point is GOOD, Center-45-M... 0.999694    0.999694
# 3   4-R.Bullock extra point is No Good, Wide Right... 0.997539    0.997539
# 4   2-J.Lambo extra point is GOOD, Center-47-M.Win... 0.997803    0.997803
# 5   5-K.Forbath extra point is GOOD, Center-47-J.D... 0.996591    0.996591
# 6   8-B.McManus extra point is GOOD, Center-46-A.B... 0.996924    0.996924
# 7   6-C.Sturgis extra point is GOOD, Center-46-J.D... 0.997539    0.997539
# 8   3-W.Lutz extra point is GOOD, Center-47-J.Dres... 0.998543    0.998543
# 9   2-N.Folk extra point is GOOD, Center-46-T.Purd... 0.997539    0.997539
# 10  shotgun TWO-POINT CONVERSION ATTEMPT. 3-R.Wils... 0.999699    0.999699
# 11  9-G.Gano extra point is GOOD, Center-44-J.Jans... 0.996808    0.996808
# 12  8-B.McManus extra point is GOOD, Center-45-T.G... 0.999694    0.999694
# 13  7-C.Catanzaro extra point is GOOD, Center-46-A... 0.999557    0.999557
# 14  5-C.Santos extra point is GOOD, Center-41-J.Wi... 0.998703    0.998703
# 15  17-G.Joseph extra point is GOOD, Center-47-C.H... 0.999699    0.999699
# 16  TWO-POINT CONVERSION ATTEMPT. 11-C.Wentz pass ... 0.996581    0.996581
# 17  TWO-POINT CONVERSION ATTEMPT. 43-D.Sproles rus... 0.996875    0.996875
# 18  4-J.Slye extra point is No Good, Wide Right, C... 0.999699    0.999699
# 19  2-B.Maher extra point is GOOD, Center-91-L.Lad... 0.996808    0.996808
# 20  3-D.Hopkins extra point is GOOD, Center-57-N.S... 0.997539    0.997539
# 21  TEN 71-Kelly eligible TWO-POINT CONVERSION ATT... 1.000000    1.000000
# 22  2-T.Bass extra point is No Good, Wide Right, C... 0.996554    0.996554
# 23  1-S.Sloman extra point is GOOD, Center-44-J.Mc... 0.997824    0.997824
# 24  TWO-POINT CONVERSION ATTEMPT. 4-D.Watson pass ... 1.000000    1.000000
# 25  2-C.Parkey extra point is GOOD, Center-47-C.Hu... 0.996581    0.996581
# 26  TWO-POINT CONVERSION ATTEMPT. 22-D.Henry rushe... 0.996808    0.996808
# 27  7-Y.Koo extra point is GOOD, Center-47-J.Harri... 0.996554    0.996554
# 28  14-J.Slye extra point is GOOD, Center-46-T.Pep... 0.998543    0.998543
# 29  16-B.Johnson extra point is GOOD, Center-54-C.... 0.996808    0.996808
# 30  6-D.Hopkins extra point is GOOD, Center-54-M.O... 0.997539    0.997539
# 31  15-E.Pineiro extra point is GOOD, Center-42-T.... 0.997539    0.997539
# 32  10-R.Patterson extra point is GOOD, Center-46-... 0.996924    0.996924
# 33  TWO-POINT CONVERSION ATTEMPT. 15-P.Mahomes pas... 0.997734    0.997734
# 34  9-C.Boswell extra point is GOOD, Center-46-C.K... 0.997202    0.997202
# 35  TWO-POINT CONVERSION ATTEMPT. 12-A.Rodgers pas... 1.000000    1.000000
# 36  8-B.McManus extra point is GOOD, Center-46-J.B... 0.996638    0.996638
# 37  1-G.Joseph extra point is GOOD, Center-42-A.De... 0.999694    0.999694
# 38  7-H.Butker extra point is GOOD, Center-41-J.Wi... 0.997539    0.997539
# 39  8-L.Havrisik extra point is GOOD, Center-47-A.... 0.999699    0.999699
# 40  5-J.Myers extra point is GOOD, Center-41-C.Sto... 0.996699    0.996699
# 41  8-L.Havrisik extra point is No Good, Wide Left... 0.997098    0.997098
# 42  16-J.Karty extra point is GOOD, Center-47-A.Wa... 0.998543    0.998543
# 43  18-A.Carlson extra point is GOOD, Center-42-T.... 0.996808    0.996808
# 44  TWO-POINT CONVERSION ATTEMPT. 8-L.Jackson pass... 0.996808    0.996808
# 45  17-B.Aubrey extra point is GOOD, Center-44-T.S... 1.000000    1.000000
# 46  16-J.Karty extra point is GOOD, Center-47-A.Wa... 0.996875    0.996875
# 47  8-C.Santos extra point is GOOD, Center-46-S.Da... 0.997202    0.997202
# 48  4-C.McLaughlin extra point is GOOD, Center-86-... 1.000000    1.000000
# 49  7-H.Butker extra point is GOOD, Center-41-J.Wi... 0.996924    0.996924
#
#     wp_2pt_good
# 0      0.997667
# 1      0.998129
# 2      1.000000
# 3      0.998465
# 4      0.998730
# 5      0.997517
# 6      0.997851
# 7      0.998465
# 8      0.999470
# 9      0.998465
# 10     1.000000
# 11     0.997734
# 12     1.000000
# 13     1.000000
# 14     0.999383
# 15     1.000000
# 16     0.997508
# 17     0.997605
# 18     1.000000
# 19     0.997734
# 20     0.998465
# 21     1.000000
# 22     0.997480
# 23     0.998750
# 24     1.000000
# 25     0.997508
# 26     0.997734
# 27     0.997480
# 28     0.999470
# 29     0.997734
# 30     0.998465
# 31     0.998465
# 32     0.997851
# 33     0.998660
# 34     0.998129
# 35     1.000000
# 36     0.997565
# 37     1.000000
# 38     0.998465
# 39     1.000000
# 40     0.997625
# 41     0.998024
# 42     0.999470
# 43     0.997734
# 44     0.997734
# 45     1.000000
# 46     0.997605
# 47     0.998129
# 48     1.000000
# 49     0.997851

# %%
p_xp, p_2pt = 0.95, 0.50

sd7_Q4['ev_xp']  = p_xp * sd7_Q4['wp_xp_good']  + (1 - p_xp) * sd7_Q4['wp_fail']
sd7_Q4['ev_2pt'] = p_2pt * sd7_Q4['wp_2pt_good'] + (1 - p_2pt) * sd7_Q4['wp_fail']
sd7_Q4['ev_diff_2pt_minus_xp'] = sd7_Q4['ev_2pt'] - sd7_Q4['ev_xp']

sd7_Q4.to_parquet("../data/sd7_Q4.parquet")
