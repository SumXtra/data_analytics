# %%
import sys, os
sys.path.append(os.path.abspath('..'))  # go up one level from notebooks/

# %%
import nfl_data_py as nfl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import duckdb as db
from utils.wp_predict import predict_wps

# %%
seasons = list(range(2015, 2025))
pbp = nfl.import_pbp_data(seasons)

print(pbp.shape)
# Out:
# 2015 done.
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# 2022 done.
# 2023 done.
# 2024 done.
# Downcasting floats.
# (483605, 398)

# %%
pbp[['game_id','play_id','season','posteam','defteam','score_differential','wp']].head(100)
# Out:
#             game_id  play_id  season posteam defteam  score_differential  \
# 0   2015_01_BAL_DEN      1.0    2015    None    None                 NaN
# 1   2015_01_BAL_DEN     36.0    2015     BAL     DEN                 0.0
# 2   2015_01_BAL_DEN     51.0    2015     BAL     DEN                 0.0
# 3   2015_01_BAL_DEN     75.0    2015     BAL     DEN                 0.0
# 4   2015_01_BAL_DEN     96.0    2015     BAL     DEN                 0.0
# ..              ...      ...     ...     ...     ...                 ...
# 95  2015_01_BAL_DEN   2075.0    2015     DEN     BAL                -1.0
# 96  2015_01_BAL_DEN   2099.0    2015     DEN     BAL                -1.0
# 97  2015_01_BAL_DEN   2125.0    2015     BAL     DEN                 1.0
# 98  2015_01_BAL_DEN   2149.0    2015     BAL     DEN                 1.0
# 99  2015_01_BAL_DEN   2170.0    2015     BAL     DEN                 1.0
#
#           wp
# 0   0.422024
# 1   0.422024
# 2   0.422024
# 3   0.420599
# 4   0.403295
# ..       ...
# 95  0.486117
# 96  0.468685
# 97  0.564145
# 98  0.614148
# 99  0.610461
#
# [100 rows x 7 columns]

# %%
con = db.connect()
con.register("plays", pbp)

df = con.sql("""
WITH tries AS (
  SELECT
    season,
    game_id,
    play_id,
    qtr,
    game_seconds_remaining,
    posteam AS team,
    two_point_attempt,
    LOWER(COALESCE(two_point_conv_result,'')) AS two_point_conv_result,
    extra_point_attempt,
    LOWER(COALESCE(extra_point_result,''))     AS extra_point_result,
    wp,
    "desc"
  FROM plays
  WHERE qtr = 3
    AND score_differential = 15
    AND (two_point_attempt = TRUE OR extra_point_attempt = TRUE)  -- booleans
),
dedup AS (
  SELECT
    *,
    ROW_NUMBER() OVER (PARTITION BY game_id ORDER BY play_id) AS rn
  FROM tries
)
SELECT
  season,
  game_id,
  qtr,
  team               AS leading_team,
  game_seconds_remaining,
  wp,
  (two_point_attempt = TRUE) AS went_for_two,
  CASE WHEN two_point_attempt = TRUE THEN (two_point_conv_result = 'success') END AS two_point_success,
  extra_point_result,
  "desc"
FROM dedup
WHERE rn = 1
ORDER BY game_id
""").df()

# %%
sd15_Q3 = df.copy()

# manually correcting timestamps to align with PFR
sd15_Q3.loc[0, "game_seconds_remaining"] = 1584
sd15_Q3.loc[3, "game_seconds_remaining"] = 1208
sd15_Q3.loc[4, "game_seconds_remaining"] = 936
sd15_Q3.loc[31, "game_seconds_remaining"] = 1552

# %%
# Compute post-try WPs (leader perspective)
branches = sd15_Q3.apply(predict_wps, axis=1, base_margin=23)
sd15_Q3 = sd15_Q3.join(branches)
sd15_Q3.shape
sd15_Q3.head(46)
# Out:
#     season          game_id  qtr leading_team  game_seconds_remaining  \
# 0     2015  2015_10_BUF_NYJ  3.0          BUF                  1584.0
# 8   0.950742         False               <NA>               good
# 9   0.937710         False               <NA>               good
# 10  0.957148         False               <NA>               good
# 11  0.943753         False               <NA>               good
# 12  0.934646         False               <NA>               good
# 13  0.950644         False               <NA>               good
# 14  0.925113         False               <NA>               good
# 15  0.950637         False               <NA>               good
# 16  0.936351         False               <NA>               good
# 17  0.944952         False               <NA>               good
# 18  0.915977         False               <NA>               good
# 19  0.909787         False               <NA>            blocked
# 20  0.933394         False               <NA>               good
# 21  0.929009         False               <NA>               good
# 22  0.936273          True              False
# 23  0.933954         False               <NA>               good
# 24  0.945619         False               <NA>               good
# 25  0.930307         False               <NA>               good
# 26  0.922666          True              False
# 27  0.950407         False               <NA>               good
# 28  0.945058         False               <NA>               good
# 29  0.936351         False               <NA>               good
# 30  0.934627         False               <NA>               good
# 31  0.928328         False               <NA>               good
# 32  0.940583         False               <NA>               good
# 33  0.938675         False               <NA>             failed
# 34  0.925101         False               <NA>               good
# 35  0.937301         False               <NA>               good
# 36  0.891547         False               <NA>               good
# 37  0.940461         False               <NA>               good
# 38  0.934234         False               <NA>               good
# 39  0.938504          True              False
# 40  0.943583         False               <NA>               good
# 41  0.928206         False               <NA>               good
# 42  0.956604         False               <NA>               good
# 43  0.934646         False               <NA>               good
# 44  0.939074         False               <NA>               good
# 45  0.951018         False               <NA>               good
#
#                                                  desc   wp_fail  wp_xp_good  \
# 0   2-D.Carpenter extra point is GOOD, Center-65-G...  0.982986    0.982986
# 1   5-C.Santos extra point is GOOD, Center-41-J.Wi...  0.995611    0.995611
# 2   9-C.Boswell extra point is GOOD, Center-60-G.W...  0.979034    0.979034
# 3   (Pass formation) TWO-POINT CONVERSION ATTEMPT....  0.993252    0.993252
# 4   6-C.Sturgis extra point is No Good, Hit Left U...  0.996780    0.996780
# 5   4-S.Hauschka extra point is GOOD, Center-48-N....  0.989476    0.989476
# 6   3-M.Bryant extra point is GOOD, Center-47-J.Ha...  0.988729    0.988729
# 7   4-R.Succop extra point is GOOD, Center-48-B.Br...  0.997438    0.997438
# 8   4-G.Zuerlein extra point is GOOD, Center-44-J....  0.997438    0.997438
# 9   8-D.Kaser extra point is GOOD, Center-47-M.Win...  0.997438    0.997438
# 10  2-K.Forbath extra point is GOOD, Center-44-J.O...  0.996780    0.996780
# 11  7-H.Butker extra point is GOOD, Center-41-J.Wi...  0.993252    0.993252
# 12  2-M.Crosby extra point is GOOD, Center-43-H.Br...  0.989476    0.989476
# 13  4-J.Lambo extra point is GOOD, Center-45-M.Ove...  0.997885    0.997885
# 14  7-H.Butker extra point is GOOD, Center-41-J.Wi...  0.992929    0.992929
# 15  7-K.Fairbairn extra point is GOOD, Center-46-J...  0.997885    0.997885
# 16  3-W.Lutz extra point is GOOD, Center-49-Z.Wood...  0.995574    0.995574
# 17  7-K.Fairbairn extra point is GOOD, Center-46-J...  0.996780    0.996780
# 18  (Kick formation) 4-S.Hauschka extra point is G...  0.989794    0.989794
# 19  9-M.Gay extra point is Blocked (20-K.Sheffield...  0.983168    0.983168
# 20  4-S.Hauschka extra point is GOOD, Center-69-R....  0.995611    0.995611
# 21  5-J.Myers extra point is GOOD, Center-69-T.Ott...  0.993252    0.993252
# 22  TWO-POINT CONVERSION ATTEMPT. 3-D.Lock pass to...  0.995611    0.995611
# 23  2-T.Bass extra point is GOOD, Center-69-R.Ferg...  0.989794    0.989794
# 24  3-D.Hopkins extra point is GOOD, Center-57-N.S...  0.996875    0.996875
# 25  2-S.Sloman extra point is GOOD, Center-47-M.Ov...  0.994992    0.994992
# 26  TWO-POINT CONVERSION ATTEMPT. 12-A.Rodgers pas...  0.980137    0.980137
# 27  7-H.Butker extra point is GOOD, Center-41-J.Wi...  0.995611    0.995611
# 28  4-J.Elliott extra point is GOOD, Center-45-R.L...  0.997438    0.997438
# 29  5-M.Prater extra point is GOOD, Center-46-A.Br...  0.995574    0.995574
# 30  6-B.Johnson extra point is GOOD, Center-49-Z.W...  0.988087    0.988087
# 31  8-M.Gay extra point is GOOD, Center-42-M.Orzec...  0.983168    0.983168
# 32  2-T.Bass extra point is GOOD, Center-69-R.Ferg...  0.992929    0.992929
# 33  2-G.Zuerlein extra point is No Good, Hit Right...  0.997885    0.997885
# 34  9-R.Gould extra point is GOOD, Center-46-T.Pep...  0.992929    0.992929
# 35  3-R.Succop extra point is GOOD, Center-97-Z.Tr...  0.995611    0.995611
# 36  5-J.Myers extra point is GOOD, Center-46-C.Tin...  0.979034    0.979034
# 37  9-J.Tucker extra point is GOOD, Center-69-T.Ot...  0.992539    0.992539
# 38  9-C.Boswell extra point is GOOD, Center-46-C.K...  0.996171    0.996171
# 39  TWO-POINT CONVERSION ATTEMPT. 87-R.Doubs is sa...  0.995611    0.995611
# 40  37-C.Ryland extra point is GOOD, Center-49-J.C...  0.997438    0.997438
# 41  10-B.McManus extra point is GOOD, Center-46-R....  0.982369    0.982369
# 42  4-C.McLaughlin extra point is GOOD, Center-97-...  0.997438    0.997438
# 43  4-J.Moody extra point is GOOD, Center-46-T.Pep...  0.989476    0.989476
# 44  4-C.McLaughlin extra point is GOOD, Center-86-...  0.989476    0.989476
# 45  39-J.Bates extra point is GOOD, Center-49-H.Ha...  0.997200    0.997200
#
#     wp_2pt_good
# 0      0.988423
# 1      0.996341
# 2      0.985687
# 3      0.993982
# 4      0.997510
# 5      0.991221
# 6      0.990473
# 7      0.998168
# 8      0.998168
# 9      0.998168
# 10     0.997510
# 11     0.993982
# 12     0.991221
# 13     0.998615
# 14     0.994673
# 15     0.998615
# 16     0.996304
# 17     0.997510
# 18     0.991539
# 19     0.988605
# 20     0.996341
# 21     0.993982
# 22     0.996341
# 23     0.991539
# 24     0.997605
# 25     0.995721
# 26     0.986789
# 27     0.996341
# 28     0.998168
# 29     0.996304
# 30     0.989832
# 31     0.988605
# 32     0.994673
# 33     0.998615
# 34     0.994673
# 35     0.996341
# 36     0.985687
# 37     0.994284
# 38     0.996900
# 39     0.996341
# 40     0.998168
# 41     0.987805
# 42     0.998168
# 43     0.991221
# 44     0.991221
# 45     0.997930

# %%
p_xp, p_2pt = 0.95, 0.50

sd15_Q3['ev_xp']  = p_xp * sd15_Q3['wp_xp_good']  + (1 - p_xp) * sd15_Q3['wp_fail']
sd15_Q3['ev_2pt'] = p_2pt * sd15_Q3['wp_2pt_good'] + (1 - p_2pt) * sd15_Q3['wp_fail']
sd15_Q3['ev_diff_2pt_minus_xp'] = sd15_Q3['ev_2pt'] - sd15_Q3['ev_xp']

sd15_Q3.to_parquet("../data/sd15_Q3.parquet")
