# %%
import sys, os
sys.path.append(os.path.abspath('..'))  # go up one level from notebooks/

# %%
import nfl_data_py as nfl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import duckdb as db
from utils.wp_predict import predict_wps

# %%
seasons = list(range(2015, 2025))
pbp = nfl.import_pbp_data(seasons)

print(pbp.shape)
# Out:
# 2015 done.
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# 2022 done.
# 2023 done.
# 2024 done.
# Downcasting floats.
# (483605, 398)

# %%
pbp[['game_id','play_id','season','posteam','defteam','score_differential','wp']].head(100)
# Out:
#             game_id  play_id  season posteam defteam  score_differential  \
# 0   2015_01_BAL_DEN      1.0    2015    None    None                 NaN
# 1   2015_01_BAL_DEN     36.0    2015     BAL     DEN                 0.0
# 2   2015_01_BAL_DEN     51.0    2015     BAL     DEN                 0.0
# 3   2015_01_BAL_DEN     75.0    2015     BAL     DEN                 0.0
# 4   2015_01_BAL_DEN     96.0    2015     BAL     DEN                 0.0
# ..              ...      ...     ...     ...     ...                 ...
# 95  2015_01_BAL_DEN   2075.0    2015     DEN     BAL                -1.0
# 96  2015_01_BAL_DEN   2099.0    2015     DEN     BAL                -1.0
# 97  2015_01_BAL_DEN   2125.0    2015     BAL     DEN                 1.0
# 98  2015_01_BAL_DEN   2149.0    2015     BAL     DEN                 1.0
# 99  2015_01_BAL_DEN   2170.0    2015     BAL     DEN                 1.0
#
#           wp
# 0   0.422024
# 1   0.422024
# 2   0.422024
# 3   0.420599
# 4   0.403295
# ..       ...
# 95  0.486117
# 96  0.468685
# 97  0.564145
# 98  0.614148
# 99  0.610461
#
# [100 rows x 7 columns]

# %%
con = db.connect()
con.register("plays", pbp)

df = con.sql("""
WITH tries AS (
  SELECT
    season,
    game_id,
    play_id,
    qtr,
    game_seconds_remaining,
    posteam AS team,                  -- team attempting the try (the leader)
    two_point_attempt,
    LOWER(COALESCE(two_point_conv_result,'')) AS two_point_conv_result,
    extra_point_attempt,
    LOWER(COALESCE(extra_point_result,''))     AS extra_point_result,
    wp,
    "desc"
  FROM plays
  WHERE qtr = 2
    AND score_differential = 23                 -- pre-try margin +7 for the try team
    AND (two_point_attempt = 1 OR extra_point_attempt = 1)
),
-- If a game has multiple qualifying tries (rare: penalties/retries), keep the first
dedup AS (
  SELECT
    *,
    ROW_NUMBER() OVER (PARTITION BY game_id ORDER BY play_id) AS rn
  FROM tries
)
SELECT
  season,
  game_id,
  qtr,
  team               AS leading_team,
  game_seconds_remaining,
  wp,
  (two_point_attempt = 1) AS went_for_two,
  CASE WHEN two_point_attempt = 1 THEN (two_point_conv_result = 'success') END AS two_point_success,
  extra_point_result,
  "desc"
FROM dedup
WHERE rn = 1
ORDER BY game_id
""").df()

# %%
sd23_Q2 = df.copy()

# manually correcting timestamps to align with PFR
sd23_Q2.loc[0, "game_seconds_remaining"] = 1812
sd23_Q2.loc[2, "game_seconds_remaining"] = 1936
sd23_Q2.loc[4, "game_seconds_remaining"] = 1826
sd23_Q2.loc[6, "game_seconds_remaining"] = 2238

# %%
# Compute post-try WPs (leader perspective)
# 1   0.969832         False               <NA>               good
# 2   0.972102         False               <NA>               good
# 3   0.967848         False               <NA>               good
# 4   0.932666         False               <NA>               good
# 5   0.969251         False               <NA>               good
# 6   0.964777         False               <NA>               good
# 7   0.949355         False               <NA>               good
# 8   0.977708         False               <NA>               good
# 9   0.975566         False               <NA>             failed
# 10  0.961168         False               <NA>               good
# 11  0.968467         False               <NA>               good
# 12  0.954375         False               <NA>               good
# 13  0.976008         False               <NA>               good
# 14  0.961288         False               <NA>               good
# 15  0.982124         False               <NA>               good
# 16  0.953096         False               <NA>               good
# 17  0.979828         False               <NA>               good
# 18  0.968355         False               <NA>               good
# 19  0.949123         False               <NA>               good
# 20  0.958974         False               <NA>               good
# 21  0.964777         False               <NA>               good
# 22  0.974184         False               <NA>               good
# 23  0.961617         False               <NA>               good
# 24  0.974742         False               <NA>               good
# 25  0.967396         False               <NA>               good
# 26  0.942525         False               <NA>               good
# 27  0.981400         False               <NA>             failed
# 28  0.940822         False               <NA>               good
# 29  0.971030         False               <NA>               good
# 30  0.968049         False               <NA>               good
# 31  0.907867         False               <NA>               good
# 32  0.961119         False               <NA>               good
# 33  0.973149         False               <NA>               good
# 34  0.972134         False               <NA>               good
# 35  0.974751         False               <NA>               good
# 36  0.969691         False               <NA>               good
# 37  0.976214         False               <NA>               good
# 38  0.948514         False               <NA>             failed
# 39  0.979081         False               <NA>               good
#
#                                                  desc   wp_fail  wp_xp_good  \
# 0   2-M.Nugent extra point is GOOD, Center-46-C.Ha...  0.972048    0.972048
# 1   2-D.Carpenter extra point is GOOD, Center-65-G...  0.975240    0.975240
# 2   1-C.Parkey extra point is GOOD, Center-46-J.Do...  0.978983    0.978983
# 3   10-C.Barth extra point is GOOD, Center-48-A.De...  0.970208    0.970208
# 4   7-C.Catanzaro extra point is GOOD, Center-86-K...  0.970622    0.970622
# 5   (Kick formation) 3-B.Walsh extra point is GOOD...  0.969989    0.969989
# 6   4-R.Succop extra point is GOOD, Center-48-B.Br...  0.970780    0.970780
# 7   (Kick formation) 4-A.Vinatieri extra point is ...  0.971381    0.971381
# 8   3-M.Bryant extra point is GOOD, Center-47-J.Ha...  0.972048    0.972048
# 9   2-N.Folk extra point is No Good, Wide Left, Ce...  0.972278    0.972278
# 10  4-J.Elliott extra point is GOOD, Center-45-R.L...  0.972048    0.972048
# 11  (Kick formation) 2-K.Forbath extra point is GO...  0.970780    0.970780
# 12  4-S.Hauschka extra point is GOOD, Center-69-R....  0.963598    0.963598
# 13  3-S.Gostkowski extra point is GOOD, Center-49-...  0.972048    0.972048
# 14  5-M.Prater extra point is GOOD, Center-48-D.Mu...  0.972048    0.972048
# 15  2-B.Maher extra point is GOOD, Center-91-L.Lad...  0.971381    0.971381
# 16  4-S.Hauschka extra point is GOOD, Center-69-R....  0.970780    0.970780
# 17  4-A.Vinatieri extra point is GOOD, Center-46-L...  0.978983    0.978983
# 18  2-A.Rosas extra point is GOOD, Center-51-Z.DeO...  0.971522    0.971522
# 19  2-M.Nugent extra point is GOOD, Center-49-J.Ca...  0.969989    0.969989
# 20  5-J.Myers extra point is GOOD, Center-69-T.Ott...  0.970622    0.970622
# 21  9-C.Boswell extra point is GOOD, Center-57-K.C...  0.972078    0.972078
# 22  2-M.Crosby extra point is GOOD, Center-43-H.Br...  0.976599    0.976599
# 23  2-C.Parkey extra point is GOOD, Center-47-C.Hu...  0.972078    0.972078
# 24  14-R.Bullock extra point is GOOD, Center-46-M....  0.977472    0.977472
# 25  6-N.Folk extra point is GOOD, Center-49-J.Card...  0.970622    0.970622
# 26  8-M.Gay extra point is GOOD, Center-42-M.Orzec...  0.971381    0.971381
# 27  9-E.Fry extra point is No Good, Wide Left, Cen...  0.978983    0.978983
# 28  5-J.Myers extra point is GOOD, Center-69-T.Ott...  0.969975    0.969975
# 29  4-J.Elliott extra point is GOOD, Center-45-R.L...  0.976507    0.976507
# 30  15-C.Dicker extra point is GOOD, Center-47-J.H...  0.970780    0.970780
# 31  8-C.Santos extra point is GOOD, Center-48-P.Sc...  0.969975    0.969975
# 32  7-J.Sanders extra point is GOOD, Center-44-B.F...  0.969975    0.969975
# 33  7-J.Sanders extra point is GOOD, Center-44-B.F...  0.973740    0.973740
# 34  21-M.Crosby extra point is GOOD, Center-59-C.K...  0.975240    0.975240
# 35  2-T.Bass extra point is GOOD, Center-69-R.Ferg...  0.978983    0.978983
# 36  44-B.Narveson extra point is GOOD, Center-42-M...  0.972278    0.972278
# 37  39-J.Bates extra point is GOOD, Center-49-H.Ha...  0.971381    0.971381
# 38  4-C.McLaughlin extra point is No Good, Wide Le...  0.972048    0.972048
# 39  4-J.Elliott extra point is GOOD, Center-49-R.L...  0.975240    0.975240
#
#     wp_2pt_good
# 0      0.981255
# 1      0.982791
# 2      0.986534
# 3      0.979292
# 4      0.979829
# 5      0.979074
# 6      0.979864
# 7      0.979373
# 8      0.981255
# 9      0.981370
# 10     0.981255
# 11     0.979864
# 12     0.972682
# 13     0.981255
# 14     0.981255
# 15     0.979373
# 16     0.979864
# 17     0.986534
# 18     0.980606
# 19     0.979074
# 20     0.979829
# 21     0.981162
# 22     0.984150
# 23     0.981162
# 24     0.985023
# 25     0.979829
# 26     0.979373
# 27     0.986534
# 28     0.979182
# 29     0.984520
# 30     0.979864
# 31     0.979182
# 32     0.979182
# 33     0.981291
# 34     0.982791
# 35     0.986534
# 36     0.981370
# 37     0.979373
# 38     0.981255
# 39     0.982791

# %%
p_xp, p_2pt = 0.95, 0.50

sd23_Q2['ev_xp']  = p_xp * sd23_Q2['wp_xp_good']  + (1 - p_xp) * sd23_Q2['wp_fail']
sd23_Q2['ev_2pt'] = p_2pt * sd23_Q2['wp_2pt_good'] + (1 - p_2pt) * sd23_Q2['wp_fail']
sd23_Q2['ev_diff_2pt_minus_xp'] = sd23_Q2['ev_2pt'] - sd23_Q2['ev_xp']

sd23_Q2.to_parquet("../data/sd23_Q2.parquet")
